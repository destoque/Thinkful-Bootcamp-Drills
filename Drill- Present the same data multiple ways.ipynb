# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\david\\Downloads\\listings.csv')
df
# Out:
#             id                                               name   host_id  \
# 0     11204286                    Family friendly/California king  56227310
# 1      7972006                            Welcome to Sunset Suite  42066439
# 2      7727710                San Diego/Eastlake. Gated community  40606235
# 3     13124681                               Townhome in Eastlake  66918996
# 4      3469225                    Bedroom suite in Large new home   4636507
# 5       877473                      Private Bedroom in Newer Home   4636507
# 6      3124507                Great view to mountains,lake,trails  15870464
# 7      3432507                        2 bedrooms with shared bath  15870464
# 8      3249729                    Near to Olympic Training center  15870464
# 9     11756336                      Chula Vista Golf Course House  39158621
# 10    12173670                      Eastlake Green room available  65401645
# ...

# %%
plt.figure(figsize=(15, 8))
sns.violinplot(x=df['price'], color='green', alpha=.2)
plt.title('Average Airbnb Rental price in San Diego')
plt.xlabel('Price in USD')


plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.set(style="whitegrid")

ax = sns.boxplot(x=df['price'])  

plt.title('Average Airbnb Rental price in San Diego')

sns.despine(offset=10, trim=True)
ax.set(xlabel='Price in USD', ylabel='')

plt.show()

# %%
plt.figure(figsize=(20, 10))

ax = sns.boxplot(x='room_type',y='price',data=df)  
plt.title('Price by Rental Type')
sns.despine(offset=10, trim=True)
ax.set(xlabel='', ylabel='Price')

plt.show()


print ('Entire home rentals make the graph looking funny as they have a large amount of variabilty in price')
# Out:
# Entire home rentals make the graph looking funny as they have a large amount of variabilty in price

# %%
sns.set(style="darkgrid")

g = sns.factorplot(x="room_type", y="price", data=df,
                   size=6, kind="bar", palette="pastel", ci=95)
g.despine(left=True)
g.set_ylabels("Price")
g.set_xlabels("")
plt.title('Average Price per Rental Type')
plt.show()

# %%
# Setting the overall aesthetic.
#sns.set(style="whitegrid")
plt.figure(figsize=(20, 10))
n_freq=df['neighbourhood'].value_counts().nsmallest(15)
n_freq

n_df = pd.DataFrame({'neighbourhood':n_freq.index ,'count':n_freq.values})
n_df

sns.barplot(x='neighbourhood', y='count', data=n_df)




#g = sns.factorplot(x='neighbourhood', y='number of Listings', data=neighbourhood_freq)
#g.despine(left=True)
#g.set_ylabels("Number of Listings")
#g.set_xlabels("Neighbourhood")
#plt.title('Neighbourhoods with the Most Listings')
#plt.show()

# %%
n_df=df['price'].mean()
n_df
# Out:
# 212.10033292978207

# %%
sns.jointplot(df['longitude'], df['latitude'], kind='resid', size=10)
# Out:
# c:\users\david\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# c:\users\david\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
